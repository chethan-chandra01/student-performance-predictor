# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Ridge,Lasso
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
df=pd.read_csv("student_data.csv")

# %%
features=['age','traveltime','freetime','health','studytime','activities','internet','absences','G1','G2','failures']
df[features]
# Out:
#      age  traveltime  freetime  health  studytime  activities  internet  \
# 0     18           2         3       3          2           0         0
# 1     17           1         3       3          2           0         1
# 2     15           1         3       3          2           0         1
# 3     15           1         2       5          3           1         1
# 4     16           1         3       5          2           0         0
# ..   ...         ...       ...     ...        ...         ...       ...
# 390   20           1         5       4          2           0         0
# 391   17           2         4       2          1           0         1
# 392   21           1         5       3          1           0         0
# 393   18           3         4       5          1           0         1
# 394   19           1         2       5          1           0         1
#
#      absences  G1  G2  failures
# 0           6   5   6         0
# 1           4   5   5         0
# 2          10   7   8         3
# 3           2  15  14         0
# 4           4   6  10         0
# ..        ...  ..  ..       ...
# 390        11   9   9         2
# 391         3  14  16         0
# 392         3  10   8         3
# 393         0  11  12         0
# 394         5   8   9         0
#
# [395 rows x 11 columns]

# %%
le=LabelEncoder()
df['internet']=le.fit_transform(df['internet'])
df['activities']=le.fit_transform(df['activities'])

# %%
x=df[features]
y=df.G3

# %%
x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
model=Ridge()

model.fit(x_train,y_train)
# Out:
# Ridge()

# %%
model.predict([[13,2,1,2,8,1,1,0,10,15,0]])
# Out:
# c:\Users\raju1\OneDrive\Desktop\Projects\Student performance predictor\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# array([14.59737945])

# %%
pred=model.predict(x_val)
acc=r2_score(y_val,pred)
print(acc*100)
mae=mean_absolute_error(y_val,pred)
print(mae)
mse=mean_squared_error(y_val,pred)
print(mse)
# Out:
# 77.14887211105929
# 1.3653506997286604
# 4.685634574913511

# %%
model2=Lasso()
model2.fit(x_train,y_train)
# Out:
# Lasso()

# %%
predi=model2.predict(x_val)
acuc=r2_score(y_val,pred)
print(acuc*100)
maei=mean_absolute_error(y_val,pred)
print(maei)
# Out:
# 77.14887211105929
# 1.3653506997286604
