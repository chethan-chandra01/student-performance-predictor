# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
df=pd.read_csv("student_data.csv")

# %%
le=LabelEncoder()
df['internet']=le.fit_transform(df['internet'])
df['activities']=le.fit_transform(df['activities'])

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='str')

# %%
features=['age','traveltime','freetime','health','studytime','activities','internet','absences','G1','G2','failures']
df[features].head()
# Out:
#    age  traveltime  freetime  health  studytime  activities  internet  \
# 0   18           2         3       3          2           0         0
# 1   17           1         3       3          2           0         1
# 2   15           1         3       3          2           0         1
# 3   15           1         2       5          3           1         1
# 4   16           1         3       5          2           0         0
#
#    absences  G1  G2  failures
# 0         6   5   6         0
# 1         4   5   5         0
# 2        10   7   8         3
# 3         2  15  14         0
# 4         4   6  10         0

# %%
x=df[features]
y=df.G3

# %%
x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
clf=tree.DecisionTreeRegressor()
clf=clf.fit(x_train,y_train)

# %%
clf.predict([[13,2,1,2,8,1,1,0,10,15,0]])
# Out:
# c:\Users\raju1\OneDrive\Desktop\Projects\Student performance predictor\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([15.])

# %%
pred=clf.predict(x_val)
acc=r2_score(y_val,pred)
print(acc*100)
mae=mean_absolute_error(y_val,pred)
print(mae)
mse=mean_squared_error(y_val,pred)
print(mse)
# Out:
# 79.5242566232938
# 1.121212121212121
# 4.717171717171717
